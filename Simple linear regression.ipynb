# %% [markdown]
# Simple linear regression : one output row vs one input row
# hypothesis : y_hat = mx + b

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset = pd.read_csv('placement_data_SLR.csv')
dataset
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
plt.scatter(dataset['cgpa'],dataset['package'],color='red') # setting the x,y axes for the dataSet X--> CGPA , Y--> Package
plt.xlabel('CGPA')
plt.ylabel('Package (LPA)')
plt.show()

# %%
x = dataset.iloc[:,0:1] # taking CGPA as x axis
y = dataset.iloc[:,-1] # taking salary package as y axis

# %%
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
SLR = LinearRegression()
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
SLR.fit(x_train,y_train)
y_pred = SLR.predict(x_test)
y_pred
# Out:
# array([3.95611517, 3.64885452, 3.91628509, 2.87501288, 2.97174309,
#        3.67161457, 3.83662492, 3.52367426, 2.37998184, 2.57344225,
#        1.63459026, 2.55637221, 1.94754092, 2.11824128, 2.89777293,
#        2.92622299, 2.9774331 , 2.62465235, 3.2619337 , 2.32877173,
#        2.52792215, 2.89208292, 2.9774331 , 3.94473515, 2.41412191,
#        3.12537341, 3.18227354, 3.51229423, 2.64172239, 1.94185091,
#        3.23348364, 3.24486367, 2.35153178, 2.25480157, 2.95467305,
#        2.11824128, 2.8807029 , 1.75977052, 2.48809206, 3.68868461])

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test,y_pred)
r2_score
# Out:
# 0.8014188746777

# %%
plt.scatter(dataset['cgpa'],dataset['package'],color='red') # setting the x,y axes for the dataSet X--> CGPA , Y--> Package
plt.xlabel('CGPA')
plt.ylabel('Package (LPA)')
m = SLR.coef_ # gives the slope of 'best fit line'
c = SLR.intercept_ # gives the intercept of 'best fit line'
y = m*x_train+c
plt.plot(x_train,y,color='green')
plt.show()

# %%
x_sample = dataset.iloc[2:3,:1]
x_sample
# Out:
#    cgpa
# 2  7.82

# %%
y_sample = dataset.iloc[2:3,1:2]
y_sample
# Out:
#    package
# 2     3.25

# %%
y_predicted = SLR.predict(x_sample)
y_predicted
# Out:
# array([3.48384417])
